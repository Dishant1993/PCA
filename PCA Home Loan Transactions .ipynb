# %% [markdown]
# # Problem Statement

# %% [markdown]
# Lending is one of the critical functions of any bank or financial institution. Customers are provided loans across different products (home loan, loan against property etc.) at competitive interest rates for an acceptable tenure. There is always a risk that a customer may default on the loan or may try and repay the loan in advance which leads to financial losses to the business.
#
# There may not be enough data or evidence available from the past which will help the firm to predict the loan default or prepayment and mitigate the above possible risk. However, it does have information about the customer demographics, loan details, EMI transactions etc. which contributes to more than 25-30 features (high-dimension data) related to a customer’s loan account. But due to high dimensions it is difficult to identify any patterns within the data. Unsupervised learning techniques like Principal Component Analysis comes to rescue here to reduce the high dimensionality and help in further analysis and pattern recognition.

# %% [markdown]
# ## About Data

# %% [markdown]
# Data file contains information about the loan transactions done by the customer.
#
# All important details regarding the loan i.e. loan amount, interest rate, outstanding principal, loan to value ratio (Net LTV), tenure, city where the loan was originated etc. has been provided.
#
# Some of the features that correspond to multiple loan transactions (e.g. rate of interest, emi amount, frequency of emi payment etc.) for a loan account are summarized and captured for each loan account.

# %% [markdown]
# ### Import  required libraries

# %%
# !pip install factor_analyzer
# Out:
# Requirement already satisfied: factor_analyzer in c:\programdata\anaconda3\ac\lib\site-packages (0.3.2)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\ac\lib\site-packages (from factor_analyzer) (1.6.2)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\ac\lib\site-packages (from factor_analyzer) (1.2.4)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\ac\lib\site-packages (from factor_analyzer) (0.24.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\ac\lib\site-packages (from factor_analyzer) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\ac\lib\site-packages (from pandas->factor_analyzer) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\ac\lib\site-packages (from pandas->factor_analyzer) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\ac\lib\site-packages (from python-dateutil>=2.7.3->pandas->factor_analyzer) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\ac\lib\site-packages (from scikit-learn->factor_analyzer) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\ac\lib\site-packages (from scikit-learn->factor_analyzer) (2.1.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from factor_analyzer import FactorAnalyzer # Perform statistical tests before PCA

# %%
import sys

# %%
sys.path
# Out:
# ['C:\\Users\\ASUS\\OneDrive\\Desktop\\New folder\\great lakes',
#  'C:\\ProgramData\\Anaconda3\\ac\\python38.zip',
#  'C:\\ProgramData\\Anaconda3\\ac\\DLLs',
#  'C:\\ProgramData\\Anaconda3\\ac\\lib',
#  'C:\\ProgramData\\Anaconda3\\ac',
#  '',
#  'C:\\ProgramData\\Anaconda3\\ac\\lib\\site-packages',
#  'C:\\ProgramData\\Anaconda3\\ac\\lib\\site-packages\\locket-0.2.1-py3.8.egg',
#  'C:\\ProgramData\\Anaconda3\\ac\\lib\\site-packages\\win32',
#  'C:\\ProgramData\\Anaconda3\\ac\\lib\\site-packages\\win32\\lib',
#  'C:\\ProgramData\\Anaconda3\\ac\\lib\\site-packages\\Pythonwin',
#  'C:\\ProgramData\\Anaconda3\\ac\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\ASUS\\.ipython']

# %% [markdown]
# ### Read and view data

# %%
df = pd.read_excel('Short Term Home Loans.xlsx')

# %%
df.head()
# Out:
#   loan_account  age gender marital_status qualification  gross_income  \
# 0        LA492   39      F              M            UG  63542.344735
# 1        LA498   51      M              M          GRAD  81130.025032
# 2        LA500   41      M              M            UG  56298.592500
# 3        LA531   42      M              M            UG  74314.142100
# 4        LA552   27      M              S          GRAD  64255.460240
#
#     nettakehome  balance_tenure     city  completed_tenure  ...  \
# 0  63542.344735             111  MADURAI                70  ...
# 1  81130.025032             107  MADURAI                68  ...
# 2  56298.592500              50  MADURAI                70  ...
# 3  74314.142100             110  MADURAI                70  ...
# 4  64255.460240             112  MADURAI                69  ...
#
#    num_emi_changes  num_low_freq_transactions  num_of_emi_transactions  \
# 0               11                         10                       73
# 1                3                         11                       73
# 2               13                         10                       73
# 3               13                         17                       72
# 4               14                         10                       71
#
#    orignal_interest_rate  orignal_tenor  outstanding_principal  paid_interest  \
# 0              17.479728            180           9.882910e+05   9.340537e+05
# 1              17.479728            180           1.206218e+06   1.069305e+06
# 2              17.479728            120           7.137100e+05   8.303592e+05
# 3              17.479728            180           1.744746e+06   1.567354e+06
# 4              17.479728            180           1.502039e+06   1.355995e+06
#
#    paid_principal  pre_emi_dueamt  pre_emi_received_amt
# 0   212745.625226    39959.331336          39959.331336
# 1   295078.188194    78774.632736          78774.632736
# 2   487326.621863    37918.629288          37918.629288
# 3   357068.193072    29375.950152          29375.950152
# 4   299516.018579    46048.309200          46048.309200
#
# [5 rows x 42 columns]

# %%
df.shape
# Out:
# (2319, 42)

# %%
df.describe().T
# Out:
#                                       count          mean           std  \
# age                                  2319.0  3.945106e+01  8.982396e+00
# gross_income                         2319.0  8.260822e+04  1.264007e+05
# nettakehome                          2319.0  8.134619e+04  1.268459e+05
# balance_tenure                       2319.0  1.466628e+02  4.513873e+01
# completed_tenure                     2319.0  2.950367e+01  1.349025e+01
# current_interest_rate                2319.0  1.569870e+01  1.872893e+00
# current_interest_rate_max            2319.0  1.578384e+01  1.832462e+00
# current_interest_rate_min            2319.0  1.568473e+01  1.875045e+00
# current_tenor                        2319.0  1.759711e+02  4.224263e+01
# diff_current_interest_rate_max_min   2319.0  1.042883e-01  5.631563e-01
# diff_emi_amount_max_min              2319.0  5.635589e+04  1.959045e+05
# diff_original_current_interest_rate  2319.0  6.943758e-02  4.787330e-01
# diff_original_current_tenor          2319.0  4.896507e+00  2.337057e+01
# emi_amount                           2319.0  1.801202e+04  1.237318e+04
# emi_dueamt                           2319.0  1.191197e+06  1.064387e+06
# emi_received_amt                     2319.0  1.132347e+06  9.800945e+05
# excess_adjusted_amt                  2319.0  1.319928e+05  5.867103e+05
# excess_available                     2319.0  1.865469e+05  7.175169e+05
# foir                                 2319.0  4.262294e-01  1.463204e-01
# last_receipt_amount                  2319.0  4.114352e+04  1.748835e+05
# loan_amt                             2319.0  2.194991e+06  1.349637e+06
# max_emi_amount                       2319.0  5.807497e+04  1.960221e+05
# min_emi_amount                       2319.0  1.723590e+03  5.332765e+03
# monthopening                         2319.0  2.035442e+06  1.286849e+06
# net_disbursed_amt                    2319.0  2.189517e+06  1.349531e+06
# net_ltv                              2319.0  5.157001e+01  1.875792e+01
# net_receivable                       2319.0  4.978290e+03  5.257671e+05
# num_emi_changes                      2319.0  5.356188e+00  3.809970e+00
# num_low_freq_transactions            2319.0  4.567486e+00  3.610644e+00
# num_of_emi_transactions              2319.0  3.215610e+01  1.325195e+01
# orignal_interest_rate                2319.0  1.576814e+01  1.814290e+00
# orignal_tenor                        2319.0  1.808676e+02  3.585916e+01
# outstanding_principal                2319.0  1.949442e+06  1.289269e+06
# paid_interest                        2319.0  6.538977e+05  5.553356e+05
# paid_principal                       2319.0  2.389494e+05  4.546814e+05
# pre_emi_dueamt                       2319.0  5.630330e+04  1.176218e+05
# pre_emi_received_amt                 2319.0  5.562086e+04  1.155979e+05
#
#                                               min           25%           50%  \
# age                                  1.800000e+01  3.200000e+01  3.900000e+01
# gross_income                         0.000000e+00  4.189591e+04  6.184963e+04
# nettakehome                          0.000000e+00  4.109947e+04  6.050222e+04
# balance_tenure                       0.000000e+00  1.290000e+02  1.500000e+02
# completed_tenure                     0.000000e+00  2.200000e+01  2.800000e+01
# current_interest_rate                1.107466e+01  1.404621e+01  1.591904e+01
# current_interest_rate_max            1.107466e+01  1.435835e+01  1.591904e+01
# current_interest_rate_min            1.107466e+01  1.404621e+01  1.591904e+01
# current_tenor                        1.000000e+01  1.730000e+02  1.800000e+02
# diff_current_interest_rate_max_min   0.000000e+00  0.000000e+00  0.000000e+00
# diff_emi_amount_max_min              0.000000e+00  1.029850e+04  1.735000e+04
# diff_original_current_interest_rate -1.248552e+00  0.000000e+00  0.000000e+00
# diff_original_current_tenor         -9.400000e+01  0.000000e+00  0.000000e+00
# emi_amount                           1.437000e+01  9.727000e+03  1.465000e+04
# emi_dueamt                           0.000000e+00  5.517018e+05  8.936884e+05
# emi_received_amt                     0.000000e+00  5.325923e+05  8.662891e+05
# excess_adjusted_amt                  0.000000e+00  0.000000e+00  0.000000e+00
# excess_available                     0.000000e+00  0.000000e+00  1.727088e+02
# foir                                 0.000000e+00  3.400000e-01  4.200000e-01
# last_receipt_amount                  2.000000e+00  9.316000e+03  1.440500e+04
# loan_amt                             1.756516e+05  1.238569e+06  1.801555e+06
# max_emi_amount                       5.620000e+02  1.157300e+04  1.897500e+04
# min_emi_amount                       9.000000e-02  1.150000e+02  1.150000e+02
# monthopening                         1.514357e+05  1.135780e+06  1.688189e+06
# net_disbursed_amt                    1.756516e+05  1.231063e+06  1.801555e+06
# net_ltv                              5.220000e+00  3.680000e+01  5.207000e+01
# net_receivable                      -7.133502e+06 -3.259933e+02 -4.417104e-01
# num_emi_changes                      0.000000e+00  3.000000e+00  4.000000e+00
# num_low_freq_transactions            0.000000e+00  2.000000e+00  3.000000e+00
# num_of_emi_transactions              0.000000e+00  2.400000e+01  3.100000e+01
# orignal_interest_rate                1.107466e+01  1.435835e+01  1.591904e+01
# orignal_tenor                        6.000000e+01  1.800000e+02  1.800000e+02
# outstanding_principal                0.000000e+00  1.065798e+06  1.606862e+06
# paid_interest                        0.000000e+00  3.083669e+05  5.082382e+05
# paid_principal                       0.000000e+00  6.463679e+04  1.159271e+05
# pre_emi_dueamt                       0.000000e+00  5.852663e+03  1.687113e+04
# pre_emi_received_amt                 0.000000e+00  5.848246e+03  1.687113e+04
#
#                                               75%           max
# age                                  4.600000e+01  6.500000e+01
# gross_income                         9.118946e+04  4.261664e+06
# nettakehome                          9.046402e+04  4.261664e+06
# balance_tenure                       1.670000e+02  3.070000e+02
# completed_tenure                     3.700000e+01  7.000000e+01
# current_interest_rate                1.747973e+01  1.997683e+01
# current_interest_rate_max            1.747973e+01  1.997683e+01
# current_interest_rate_min            1.747973e+01  1.997683e+01
# current_tenor                        1.810000e+02  3.160000e+02
# diff_current_interest_rate_max_min   0.000000e+00  1.201107e+01
# diff_emi_amount_max_min              2.860478e+04  3.229383e+06
# diff_original_current_interest_rate  0.000000e+00  5.618484e+00
# diff_original_current_tenor          0.000000e+00  2.280000e+02
# emi_amount                           2.264000e+04  1.200000e+05
# emi_dueamt                           1.453225e+06  9.853225e+06
# emi_received_amt                     1.397185e+06  9.853225e+06
# excess_adjusted_amt                  1.091124e+03  1.020263e+07
# excess_available                     3.881751e+03  1.021953e+07
# foir                                 4.900000e-01  1.001000e+00
# last_receipt_amount                  2.307700e+04  3.229945e+06
# loan_amt                             2.818683e+06  1.089366e+07
# max_emi_amount                       2.967650e+04  3.229945e+06
# min_emi_amount                       5.730000e+02  8.400100e+04
# monthopening                         2.620309e+06  1.080242e+07
# net_disbursed_amt                    2.800199e+06  1.089366e+07
# net_ltv                              6.889000e+01  8.439000e+01
# net_receivable                       0.000000e+00  8.252080e+06
# num_emi_changes                      7.000000e+00  2.700000e+01
# num_low_freq_transactions            6.000000e+00  2.100000e+01
# num_of_emi_transactions              4.000000e+01  7.300000e+01
# orignal_interest_rate                1.747973e+01  1.997683e+01
# orignal_tenor                        1.800000e+02  2.400000e+02
# outstanding_principal                2.546081e+06  1.080242e+07
# paid_interest                        8.067100e+05  5.588191e+06
# paid_principal                       2.208857e+05  7.458322e+06
# pre_emi_dueamt                       5.423541e+04  1.624202e+06
# pre_emi_received_amt                 5.423541e+04  1.585701e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2319 entries, 0 to 2318
# Data columns (total 42 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   loan_account                         2319 non-null   object
#  1   age                                  2319 non-null   int64
#  2   gender                               2319 non-null   object
#  3   marital_status                       2319 non-null   object
#  4   qualification                        2319 non-null   object
#  5   gross_income                         2319 non-null   float64
#  6   nettakehome                          2319 non-null   float64
#  7   balance_tenure                       2319 non-null   int64
#  8   city                                 2319 non-null   object
#  9   completed_tenure                     2319 non-null   int64
#  10  current_interest_rate                2319 non-null   float64
#  11  current_interest_rate_max            2319 non-null   float64
#  12  current_interest_rate_min            2319 non-null   float64
#  13  current_tenor                        2319 non-null   int64
#  14  diff_current_interest_rate_max_min   2319 non-null   float64
#  15  diff_emi_amount_max_min              2319 non-null   float64
#  16  diff_original_current_interest_rate  2319 non-null   float64
#  17  diff_original_current_tenor          2319 non-null   int64
#  18  emi_amount                           2319 non-null   float64
#  19  emi_dueamt                           2319 non-null   float64
#  20  emi_received_amt                     2319 non-null   float64
#  21  excess_adjusted_amt                  2319 non-null   float64
#  22  excess_available                     2319 non-null   float64
#  23  foir                                 2319 non-null   float64
#  24  last_receipt_amount                  2319 non-null   float64
#  25  loan_amt                             2319 non-null   float64
#  26  max_emi_amount                       2319 non-null   float64
#  27  min_emi_amount                       2319 non-null   float64
#  28  monthopening                         2319 non-null   float64
#  29  net_disbursed_amt                    2319 non-null   float64
#  30  net_ltv                              2319 non-null   float64
#  31  net_receivable                       2319 non-null   float64
#  32  num_emi_changes                      2319 non-null   int64
#  33  num_low_freq_transactions            2319 non-null   int64
#  34  num_of_emi_transactions              2319 non-null   int64
#  35  orignal_interest_rate                2319 non-null   float64
#  36  orignal_tenor                        2319 non-null   int64
#  37  outstanding_principal                2319 non-null   float64
#  38  paid_interest                        2319 non-null   float64
#  39  paid_principal                       2319 non-null   float64
#  40  pre_emi_dueamt                       2319 non-null   float64
#  41  pre_emi_received_amt                 2319 non-null   float64
# dtypes: float64(28), int64(9), object(5)
# memory usage: 761.0+ KB

# %%
df.city.value_counts()
# Out:
# MUMBAI             586
# HYDERABAD          268
# AHMEDABAD          165
# CHENNAI            164
# MADURAI            157
# COIMBATORE         156
# SURAT              136
# ERODE               85
# PUNE                78
# TIRUCHIRAPPALLI     78
# KARUR               65
# TUTICORIN           64
# TIRUPUR             63
# WARANGAL            56
# NAMAKKAL            56
# VISHAKHAPATNAM      45
# BANGALORE           45
# Hyd                 31
# Mum                 21
# Name: city, dtype: int64

# %%
df.gender.value_counts()
# Out:
# M    1994
# F     325
# Name: gender, dtype: int64

# %%
df.marital_status.value_counts()
# Out:
# M    2086
# S     233
# Name: marital_status, dtype: int64

# %%
df.qualification.value_counts()
# Out:
# UG          1548
# GRAD         409
# POSTGRAD     181
# OTHERS       150
# PRF           18
# ENG            6
# MAT            5
# DOCTRATE       2
# Name: qualification, dtype: int64

# %% [markdown]
# #### Observations:

# %% [markdown]
# ### Data Cleanup

# %%
df.city.replace(to_replace='Mum',value='MUMBAI',inplace=True)
df.city.replace(to_replace='Hyd',value='HYDERABAD',inplace=True)
df.city.value_counts()
# Out:
# MUMBAI             607
# HYDERABAD          299
# AHMEDABAD          165
# CHENNAI            164
# MADURAI            157
# COIMBATORE         156
# SURAT              136
# ERODE               85
# PUNE                78
# TIRUCHIRAPPALLI     78
# KARUR               65
# TUTICORIN           64
# TIRUPUR             63
# NAMAKKAL            56
# WARANGAL            56
# BANGALORE           45
# VISHAKHAPATNAM      45
# Name: city, dtype: int64

# %%
df.drop(['diff_current_interest_rate_max_min','diff_original_current_interest_rate','diff_original_current_tenor','excess_adjusted_amt'], axis=1, inplace=True)

# %%
df.gross_income.replace(to_replace=0, value=df.gross_income.median(),inplace=True)
df.nettakehome.replace(to_replace=0, value=df.nettakehome.median(),inplace=True)

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Univariate Analysis

# %%
def univariateAnalysis_numeric(column,nbins):
    print("Description of " + column)
    print("----------------------------------------------------------------------------")
    print(df[column].describe(),end=' ')
    
    
    plt.figure()
    print("Distribution of " + column)
    print("----------------------------------------------------------------------------")
    sns.distplot(df[column], kde=False, color='g', bins=nbins);
    plt.show()
    
    plt.figure()
    print("BoxPlot of " + column)
    print("----------------------------------------------------------------------------")
    ax = sns.boxplot(x=df[column])
    plt.show()

# %%
univariateAnalysis_numeric('age',20)
# Out:
# Description of age
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       39.451056
# std         8.982396
# min        18.000000
# 25%        32.000000
# 50%        39.000000
# 75%        46.000000
# max        65.000000
# Name: age, dtype: float64 Distribution of age
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of age
# ----------------------------------------------------------------------------

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
lstnumericcolumns = list(df_num.columns.values)
len(lstnumericcolumns)
# Out:
# 33

# %%
for x in lstnumericcolumns:
    univariateAnalysis_numeric(x,20)
# Out:
# Description of age
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       39.451056
# std         8.982396
# min        18.000000
# 25%        32.000000
# 50%        39.000000
# 75%        46.000000
# max        65.000000
# Name: age, dtype: float64 Distribution of age
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of age
# ----------------------------------------------------------------------------
# Description of gross_income
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     8.274157e+04
# std      1.263460e+05
# min      1.250579e+01
# 25%      4.203628e+04
# 50%      6.184963e+04
# 75%      9.118946e+04
# max      4.261664e+06
# Name: gross_income, dtype: float64 Distribution of gross_income
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of gross_income
# ----------------------------------------------------------------------------
# Description of nettakehome
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     8.194625e+04
# std      1.266025e+05
# min      1.246076e-01
# 25%      4.198749e+04
# 50%      6.050222e+04
# 75%      9.046402e+04
# max      4.261664e+06
# Name: nettakehome, dtype: float64 Distribution of nettakehome
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of nettakehome
# ----------------------------------------------------------------------------
# Description of balance_tenure
# ----------------------------------------------------------------------------
# count    2319.000000
# mean      146.662786
# std        45.138729
# min         0.000000
# 25%       129.000000
# 50%       150.000000
# 75%       167.000000
# max       307.000000
# Name: balance_tenure, dtype: float64 Distribution of balance_tenure
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of balance_tenure
# ----------------------------------------------------------------------------
# Description of completed_tenure
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       29.503665
# std        13.490253
# min         0.000000
# 25%        22.000000
# 50%        28.000000
# 75%        37.000000
# max        70.000000
# Name: completed_tenure, dtype: float64 Distribution of completed_tenure
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of completed_tenure
# ----------------------------------------------------------------------------
# Description of current_interest_rate
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       15.698703
# std         1.872893
# min        11.074656
# 25%        14.046210
# 50%        15.919038
# 75%        17.479728
# max        19.976832
# Name: current_interest_rate, dtype: float64 Distribution of current_interest_rate
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of current_interest_rate
# ----------------------------------------------------------------------------
# Description of current_interest_rate_max
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       15.783840
# std         1.832462
# min        11.074656
# 25%        14.358348
# 50%        15.919038
# 75%        17.479728
# max        19.976832
# Name: current_interest_rate_max, dtype: float64 Distribution of current_interest_rate_max
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of current_interest_rate_max
# ----------------------------------------------------------------------------
# Description of current_interest_rate_min
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       15.684731
# std         1.875045
# min        11.074656
# 25%        14.046210
# 50%        15.919038
# 75%        17.479728
# max        19.976832
# Name: current_interest_rate_min, dtype: float64 Distribution of current_interest_rate_min
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of current_interest_rate_min
# ----------------------------------------------------------------------------
# Description of current_tenor
# ----------------------------------------------------------------------------
# count    2319.000000
# mean      175.971108
# std        42.242628
# min        10.000000
# 25%       173.000000
# 50%       180.000000
# 75%       181.000000
# max       316.000000
# Name: current_tenor, dtype: float64 Distribution of current_tenor
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of current_tenor
# ----------------------------------------------------------------------------
# Description of diff_emi_amount_max_min
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     5.635589e+04
# std      1.959045e+05
# min      0.000000e+00
# 25%      1.029850e+04
# 50%      1.735000e+04
# 75%      2.860478e+04
# max      3.229383e+06
# Name: diff_emi_amount_max_min, dtype: float64 Distribution of diff_emi_amount_max_min
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of diff_emi_amount_max_min
# ----------------------------------------------------------------------------
# Description of emi_amount
# ----------------------------------------------------------------------------
# count      2319.000000
# mean      18012.023109
# std       12373.175124
# min          14.370000
# 25%        9727.000000
# 50%       14650.000000
# 75%       22640.000000
# max      120000.000000
# Name: emi_amount, dtype: float64 Distribution of emi_amount
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of emi_amount
# ----------------------------------------------------------------------------
# Description of emi_dueamt
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     1.191197e+06
# std      1.064387e+06
# min      0.000000e+00
# 25%      5.517018e+05
# 50%      8.936884e+05
# 75%      1.453225e+06
# max      9.853225e+06
# Name: emi_dueamt, dtype: float64 Distribution of emi_dueamt
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of emi_dueamt
# ----------------------------------------------------------------------------
# Description of emi_received_amt
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     1.132347e+06
# std      9.800945e+05
# min      0.000000e+00
# 25%      5.325923e+05
# 50%      8.662891e+05
# 75%      1.397185e+06
# max      9.853225e+06
# Name: emi_received_amt, dtype: float64 Distribution of emi_received_amt
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of emi_received_amt
# ----------------------------------------------------------------------------
# Description of excess_available
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     1.865469e+05
# std      7.175169e+05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.727088e+02
# 75%      3.881751e+03
# max      1.021953e+07
# Name: excess_available, dtype: float64 Distribution of excess_available
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of excess_available
# ----------------------------------------------------------------------------
# Description of foir
# ----------------------------------------------------------------------------
# count    2319.000000
# mean        0.426229
# std         0.146320
# min         0.000000
# 25%         0.340000
# 50%         0.420000
# 75%         0.490000
# max         1.001000
# Name: foir, dtype: float64 Distribution of foir
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of foir
# ----------------------------------------------------------------------------
# Description of last_receipt_amount
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     4.114352e+04
# std      1.748835e+05
# min      2.000000e+00
# 25%      9.316000e+03
# 50%      1.440500e+04
# 75%      2.307700e+04
# max      3.229945e+06
# Name: last_receipt_amount, dtype: float64 Distribution of last_receipt_amount
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of last_receipt_amount
# ----------------------------------------------------------------------------
# Description of loan_amt
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     2.194991e+06
# std      1.349637e+06
# min      1.756516e+05
# 25%      1.238569e+06
# 50%      1.801555e+06
# 75%      2.818683e+06
# max      1.089366e+07
# Name: loan_amt, dtype: float64 Distribution of loan_amt
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of loan_amt
# ----------------------------------------------------------------------------
# Description of max_emi_amount
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     5.807497e+04
# std      1.960221e+05
# min      5.620000e+02
# 25%      1.157300e+04
# 50%      1.897500e+04
# 75%      2.967650e+04
# max      3.229945e+06
# Name: max_emi_amount, dtype: float64 Distribution of max_emi_amount
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of max_emi_amount
# ----------------------------------------------------------------------------
# Description of min_emi_amount
# ----------------------------------------------------------------------------
# count     2319.000000
# mean      1723.590298
# std       5332.764547
# min          0.090000
# 25%        115.000000
# 50%        115.000000
# 75%        573.000000
# max      84001.000000
# Name: min_emi_amount, dtype: float64 Distribution of min_emi_amount
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of min_emi_amount
# ----------------------------------------------------------------------------
# Description of monthopening
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     2.035442e+06
# std      1.286849e+06
# min      1.514357e+05
# 25%      1.135780e+06
# 50%      1.688189e+06
# 75%      2.620309e+06
# max      1.080242e+07
# Name: monthopening, dtype: float64 Distribution of monthopening
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of monthopening
# ----------------------------------------------------------------------------
# Description of net_disbursed_amt
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     2.189517e+06
# std      1.349531e+06
# min      1.756516e+05
# 25%      1.231063e+06
# 50%      1.801555e+06
# 75%      2.800199e+06
# max      1.089366e+07
# Name: net_disbursed_amt, dtype: float64 Distribution of net_disbursed_amt
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of net_disbursed_amt
# ----------------------------------------------------------------------------
# Description of net_ltv
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       51.570013
# std        18.757921
# min         5.220000
# 25%        36.800000
# 50%        52.070000
# 75%        68.890000
# max        84.390000
# Name: net_ltv, dtype: float64 Distribution of net_ltv
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of net_ltv
# ----------------------------------------------------------------------------
# Description of net_receivable
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     4.978290e+03
# std      5.257671e+05
# min     -7.133502e+06
# 25%     -3.259933e+02
# 50%     -4.417104e-01
# 75%      0.000000e+00
# max      8.252080e+06
# Name: net_receivable, dtype: float64 Distribution of net_receivable
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of net_receivable
# ----------------------------------------------------------------------------
# Description of num_emi_changes
# ----------------------------------------------------------------------------
# count    2319.000000
# mean        5.356188
# std         3.809970
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         7.000000
# max        27.000000
# Name: num_emi_changes, dtype: float64 Distribution of num_emi_changes
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of num_emi_changes
# ----------------------------------------------------------------------------
# Description of num_low_freq_transactions
# ----------------------------------------------------------------------------
# count    2319.000000
# mean        4.567486
# std         3.610644
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max        21.000000
# Name: num_low_freq_transactions, dtype: float64 Distribution of num_low_freq_transactions
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of num_low_freq_transactions
# ----------------------------------------------------------------------------
# Description of num_of_emi_transactions
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       32.156102
# std        13.251947
# min         0.000000
# 25%        24.000000
# 50%        31.000000
# 75%        40.000000
# max        73.000000
# Name: num_of_emi_transactions, dtype: float64 Distribution of num_of_emi_transactions
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of num_of_emi_transactions
# ----------------------------------------------------------------------------
# Description of orignal_interest_rate
# ----------------------------------------------------------------------------
# count    2319.000000
# mean       15.768140
# std         1.814290
# min        11.074656
# 25%        14.358348
# 50%        15.919038
# 75%        17.479728
# max        19.976832
# Name: orignal_interest_rate, dtype: float64 Distribution of orignal_interest_rate
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of orignal_interest_rate
# ----------------------------------------------------------------------------
# Description of orignal_tenor
# ----------------------------------------------------------------------------
# count    2319.000000
# mean      180.867615
# std        35.859160
# min        60.000000
# 25%       180.000000
# 50%       180.000000
# 75%       180.000000
# max       240.000000
# Name: orignal_tenor, dtype: float64 Distribution of orignal_tenor
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of orignal_tenor
# ----------------------------------------------------------------------------
# Description of outstanding_principal
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     1.949442e+06
# std      1.289269e+06
# min      0.000000e+00
# 25%      1.065798e+06
# 50%      1.606862e+06
# 75%      2.546081e+06
# max      1.080242e+07
# Name: outstanding_principal, dtype: float64 Distribution of outstanding_principal
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of outstanding_principal
# ----------------------------------------------------------------------------
# Description of paid_interest
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     6.538977e+05
# std      5.553356e+05
# min      0.000000e+00
# 25%      3.083669e+05
# 50%      5.082382e+05
# 75%      8.067100e+05
# max      5.588191e+06
# Name: paid_interest, dtype: float64 Distribution of paid_interest
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of paid_interest
# ----------------------------------------------------------------------------
# Description of paid_principal
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     2.389494e+05
# std      4.546814e+05
# min      0.000000e+00
# 25%      6.463679e+04
# 50%      1.159271e+05
# 75%      2.208857e+05
# max      7.458322e+06
# Name: paid_principal, dtype: float64 Distribution of paid_principal
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of paid_principal
# ----------------------------------------------------------------------------
# Description of pre_emi_dueamt
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     5.630330e+04
# std      1.176218e+05
# min      0.000000e+00
# 25%      5.852663e+03
# 50%      1.687113e+04
# 75%      5.423541e+04
# max      1.624202e+06
# Name: pre_emi_dueamt, dtype: float64 Distribution of pre_emi_dueamt
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of pre_emi_dueamt
# ----------------------------------------------------------------------------
# Description of pre_emi_received_amt
# ----------------------------------------------------------------------------
# count    2.319000e+03
# mean     5.562086e+04
# std      1.155979e+05
# min      0.000000e+00
# 25%      5.848246e+03
# 50%      1.687113e+04
# 75%      5.423541e+04
# max      1.585701e+06
# Name: pre_emi_received_amt, dtype: float64 Distribution of pre_emi_received_amt
# ----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BoxPlot of pre_emi_received_amt
# ----------------------------------------------------------------------------

# %% [markdown]
# #### Observations

# %%
df.num_low_freq_transactions.describe()
# Out:
# count    2319.000000
# mean        4.567486
# std         3.610644
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max        21.000000
# Name: num_low_freq_transactions, dtype: float64

# %%
# Probable customers who are paying off their loans earlier
df[df.num_low_freq_transactions > 6]
# Out:
#      loan_account  age gender marital_status qualification  gross_income  \
# 0           LA492   39      F              M            UG  63542.344735
# 1           LA498   51      M              M          GRAD  81130.025032
# 2           LA500   41      M              M            UG  56298.592500
# 3           LA531   42      M              M            UG  74314.142100
# 4           LA552   27      M              S          GRAD  64255.460240
# ...           ...  ...    ...            ...           ...           ...
# 2293       LA5669   32      M              M            UG  40122.505579
# 2301       LA5697   44      M              M          GRAD  82314.051991
# 2303       LA5699   35      M              M           MAT  74407.477660
# 2308       LA5709   53      M              M            UG  73053.053628
# 2315       LA5726   34      M              M            UG  61849.633721
#
#        nettakehome  balance_tenure      city  completed_tenure  ...  \
# 0     63542.344735             111   MADURAI                70  ...
# 1     81130.025032             107   MADURAI                68  ...
# 2     56298.592500              50   MADURAI                70  ...
# 3     74314.142100             110   MADURAI                70  ...
# 4     64255.460240             112   MADURAI                69  ...
# ...            ...             ...       ...               ...  ...
# 2293  40122.505579             220    MUMBAI                20  ...
# 2301  82314.047487             240    MUMBAI                 0  ...
# 2303  74407.477660             223    MUMBAI                17  ...
# 2308  73053.053628             187  NAMAKKAL                17  ...
# 2315  60502.220740             240    MUMBAI                 0  ...
#
#       num_emi_changes  num_low_freq_transactions  num_of_emi_transactions  \
# 0                  11                         10                       73
# 1                   3                         11                       73
# 2                  13                         10                       73
# 3                  13                         17                       72
# 4                  14                         10                       71
# ...               ...                        ...                      ...
# 2293               13                          7                       20
# 2301                4                          8                       18
# 2303                7                          8                       22
# 2308                9                          9                       22
# 2315                7                          8                       18
#
#       orignal_interest_rate  orignal_tenor  outstanding_principal  \
# 0                 17.479728            180           9.882910e+05
# 1                 17.479728            180           1.206218e+06
# 2                 17.479728            120           7.137100e+05
# 3                 17.479728            180           1.744746e+06
# 4                 17.479728            180           1.502039e+06
# ...                     ...            ...                    ...
# 2293              14.358348            240           2.180859e+06
# 2301              14.358348            240           1.524213e+06
# 2303              14.046210            240           2.753524e+06
# 2308              16.231176            204           2.488135e+06
# 2315              14.358348            240           1.280237e+06
#
#       paid_interest  paid_principal  pre_emi_dueamt  pre_emi_received_amt
# 0      9.340537e+05   212745.625226    39959.331336          39959.331336
# 1      1.069305e+06   295078.188194    78774.632736          78774.632736
# 2      8.303592e+05   487326.621863    37918.629288          37918.629288
# 3      1.567354e+06   357068.193072    29375.950152          29375.950152
# 4      1.355995e+06   299516.018579    46048.309200          46048.309200
# ...             ...             ...             ...                   ...
# 2293   3.936277e+05    47058.116851     5236.476792           5236.476792
# 2301   7.913330e+04        0.000000   376421.185776         116412.775920
# 2303   5.205503e+05    53899.521812   151519.918512         151519.918512
# 2308   5.596275e+05    64067.798265   139688.705448         139688.705448
# 2315   1.305872e+05        0.000000   316114.464864         192106.478616
#
# [535 rows x 38 columns]

# %% [markdown]
# #### Observation

# %%
def univariateAnalysis_category(cat_column):
    print("Details of " + cat_column)
    print("----------------------------------------------------------------")
    print(df_cat[cat_column].value_counts())
    plt.figure()
    df_cat[cat_column].value_counts().plot.bar(title="Frequency Distribution of " + cat_column)
    plt.show()
    print("       ")

# %%
df_cat = df.select_dtypes(include = ['object'])
lstcatcolumns = list(df_cat.columns.values)
lstcatcolumns
# Out:
# ['loan_account', 'gender', 'marital_status', 'qualification', 'city']

# %%
lstcatcolumns.remove('loan_account')

# %%
for x in lstcatcolumns:
    univariateAnalysis_category(x)
# Out:
# Details of gender
# ----------------------------------------------------------------
# M    1994
# F     325
# Name: gender, dtype: int64
#
# Details of marital_status
# ----------------------------------------------------------------
# M    2086
# S     233
# Name: marital_status, dtype: int64
#
# Details of qualification
# ----------------------------------------------------------------
# UG          1548
# GRAD         409
# POSTGRAD     181
# OTHERS       150
# PRF           18
# ENG            6
# MAT            5
# DOCTRATE       2
# Name: qualification, dtype: int64
#
# Details of city
# ----------------------------------------------------------------
# MUMBAI             607
# HYDERABAD          299
# AHMEDABAD          165
# CHENNAI            164
# MADURAI            157
# COIMBATORE         156
# SURAT              136
# ERODE               85
# PUNE                78
# TIRUCHIRAPPALLI     78
# KARUR               65
# TUTICORIN           64
# TIRUPUR             63
# NAMAKKAL            56
# WARANGAL            56
# BANGALORE           45
# VISHAKHAPATNAM      45
# Name: city, dtype: int64

# %% [markdown]
# #### Bivariate Analysis

# %%
corr = df_num.corr(method='pearson')

# %%
mask = np.triu(np.ones_like(corr, dtype=np.bool)) 
fig = plt.subplots(figsize=(25, 15))
sns.heatmap(df_num.corr(), annot=True,fmt='.2f',mask=mask)
plt.show()
# Out:
# <ipython-input-33-9c73085bab70>:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(corr, dtype=np.bool))

# %% [markdown]
# #### Observation

# %% [markdown]
# ### Outlier Treatment

# %%
df_num.boxplot(figsize=(20,20))
plt.xticks(rotation=90)
plt.show()

# %%
no_outlier = ['age','current_interest_rate','current_interest_rate_max','current_interest_rate_min','net_ltv','orignal_interest_rate']

# %%
df_num[no_outlier].boxplot(figsize=(20,20))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# To treat outliers lets define a function **'treat_outlier'**.
#
# - For the higher outliers we will treat it to get it at 95 percentile value.
#
# - Lower level outliers will be treated to get it at 5 percentile value.

# %%
def treat_outlier(x):
    # taking 5,25,75 percentile of column
    q5= np.percentile(x,5)
    q25=np.percentile(x,25)
    q75=np.percentile(x,75)
    dt=np.percentile(x,95)
    #calculationg IQR range
    IQR=q75-q25
    #Calculating minimum threshold
    lower_bound=q25-(1.5*IQR)
    upper_bound=q75+(1.5*IQR)
    #Capping outliers
    return x.apply(lambda y: dt if y > upper_bound else y).apply(lambda y: q5 if y < lower_bound else y)

# %%
outlier_list = [x for x in df_num.columns if x not in no_outlier]

# %%
for i in df_num[outlier_list]:    
    df_num[i]=treat_outlier(df_num[i])

# %%
df_num.boxplot(figsize=(20,20))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## PCA

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, age to pre_emi_received_amt
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        33 non-null     float64
#  1   gross_income               33 non-null     float64
#  2   nettakehome                33 non-null     float64
#  3   balance_tenure             33 non-null     float64
#  4   completed_tenure           33 non-null     float64
#  5   current_interest_rate      33 non-null     float64
#  6   current_interest_rate_max  33 non-null     float64
#  7   current_interest_rate_min  33 non-null     float64
#  8   current_tenor              33 non-null     float64
#  9   diff_emi_amount_max_min    33 non-null     float64
#  10  emi_amount                 33 non-null     float64
#  11  emi_dueamt                 33 non-null     float64
#  12  emi_received_amt           33 non-null     float64
#  13  excess_available           33 non-null     float64
#  14  foir                       33 non-null     float64
#  15  last_receipt_amount        33 non-null     float64
#  16  loan_amt                   33 non-null     float64
#  17  max_emi_amount             33 non-null     float64
#  18  min_emi_amount             33 non-null     float64
#  19  monthopening               33 non-null     float64
#  20  net_disbursed_amt          33 non-null     float64
#  21  net_ltv                    33 non-null     float64
#  22  net_receivable             33 non-null     float64
#  23  num_emi_changes            33 non-null     float64
#  24  num_low_freq_transactions  33 non-null     float64
#  25  num_of_emi_transactions    33 non-null     float64
#  26  orignal_interest_rate      33 non-null     float64
#  27  orignal_tenor              33 non-null     float64
#  28  outstanding_principal      33 non-null     float64
#  29  paid_interest              33 non-null     float64
#  30  paid_principal             33 non-null     float64
#  31  pre_emi_dueamt             33 non-null     float64
#  32  pre_emi_received_amt       33 non-null     float64
# dtypes: float64(33)
# memory usage: 9.8+ KB

# %%
from scipy.stats import zscore
df_num_scaled=df_num.apply(zscore)
df_num_scaled.head()
# Out:
#                        age  gross_income  nettakehome  balance_tenure  \
# age               3.343371     -0.251494    -0.259055       -0.991086
# gross_income      0.162973      2.231784     2.246354       -0.058124
# nettakehome       0.150452      2.231784     2.246354       -0.043652
# balance_tenure   -2.069684     -1.205985    -1.177219        2.386743
# completed_tenure  0.582316     -0.849304    -0.881185       -1.090615
#
#                   completed_tenure  current_interest_rate  \
# age                       0.243205               0.211219
# gross_income             -0.406152               0.092748
# nettakehome              -0.426779               0.080917
# balance_tenure           -1.761636              -1.647172
# completed_tenure          2.215396               0.635806
#
#                   current_interest_rate_max  current_interest_rate_min  \
# age                                0.201869                   0.217756
# gross_income                       0.065401                   0.090806
# nettakehome                        0.052853                   0.079049
# balance_tenure                    -1.706484                  -1.645375
# completed_tenure                   0.685400                   0.639494
#
#                   current_tenor  diff_emi_amount_max_min  ...  \
# age                   -1.144218                -0.102357  ...
# gross_income          -0.193030                -0.472507  ...
# nettakehome           -0.181359                -0.471168  ...
# balance_tenure         2.535198                -0.751369  ...
# completed_tenure      -0.681755                -0.325947  ...
#
#                   num_emi_changes  num_low_freq_transactions  \
# age                      0.163974                   0.155591
# gross_income            -0.633921                  -0.452820
# nettakehome             -0.638758                  -0.463850
# balance_tenure          -0.980047                  -1.485457
# completed_tenure         1.096909                   1.546327
#
#                   num_of_emi_transactions  orignal_interest_rate  \
# age                              0.274748               0.208265
# gross_income                    -0.482762               0.066743
# nettakehome                     -0.502126               0.054306
# balance_tenure                  -1.696575              -1.697443
# completed_tenure                 2.166510               0.681175
#
#                   orignal_tenor  outstanding_principal  paid_interest  \
# age                   -1.285955              -0.978414      -0.679942
# gross_income          -0.236180               0.321144      -0.049340
# nettakehome           -0.223795               0.318282      -0.072739
# balance_tenure         2.524143               0.080771      -2.009018
# completed_tenure      -0.715187              -1.309480       0.583510
#
#                   paid_principal  pre_emi_dueamt  pre_emi_received_amt
# age                     0.350857       -0.308396             -0.310736
# gross_income            0.044279       -0.309388             -0.305537
# nettakehome             0.028365       -0.302623             -0.299446
# balance_tenure         -2.439701        0.104583              0.037512
# completed_tenure        0.609293       -1.467359             -1.444988
#
# [5 rows x 33 columns]

# %%
df_num_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, age to pre_emi_received_amt
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        33 non-null     float64
#  1   gross_income               33 non-null     float64
#  2   nettakehome                33 non-null     float64
#  3   balance_tenure             33 non-null     float64
#  4   completed_tenure           33 non-null     float64
#  5   current_interest_rate      33 non-null     float64
#  6   current_interest_rate_max  33 non-null     float64
#  7   current_interest_rate_min  33 non-null     float64
#  8   current_tenor              33 non-null     float64
#  9   diff_emi_amount_max_min    33 non-null     float64
#  10  emi_amount                 33 non-null     float64
#  11  emi_dueamt                 33 non-null     float64
#  12  emi_received_amt           33 non-null     float64
#  13  excess_available           33 non-null     float64
#  14  foir                       33 non-null     float64
#  15  last_receipt_amount        33 non-null     float64
#  16  loan_amt                   33 non-null     float64
#  17  max_emi_amount             33 non-null     float64
#  18  min_emi_amount             33 non-null     float64
#  19  monthopening               33 non-null     float64
#  20  net_disbursed_amt          33 non-null     float64
#  21  net_ltv                    33 non-null     float64
#  22  net_receivable             33 non-null     float64
#  23  num_emi_changes            33 non-null     float64
#  24  num_low_freq_transactions  33 non-null     float64
#  25  num_of_emi_transactions    33 non-null     float64
#  26  orignal_interest_rate      33 non-null     float64
#  27  orignal_tenor              33 non-null     float64
#  28  outstanding_principal      33 non-null     float64
#  29  paid_interest              33 non-null     float64
#  30  paid_principal             33 non-null     float64
#  31  pre_emi_dueamt             33 non-null     float64
#  32  pre_emi_received_amt       33 non-null     float64
# dtypes: float64(33)
# memory usage: 9.8+ KB

# %%
df_num_scaled.boxplot(figsize=(20,3))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Statistical tests to be done before PCA

# %% [markdown]
# #### Bartletts Test of Sphericity
# Bartlett's test of sphericity tests the hypothesis that the variables are uncorrelated in the population.
#
# - H0: All variables in the data are uncorrelated
# - Ha: At least one pair of variables in the data are correlated
#
# If the null hypothesis cannot be rejected, then PCA is not advisable.
#
# If the p-value is small, then we can reject the null hypothesis and agree that there is atleast one pair of vairbales in the data wihich are correlated hence PCA is recommended.

# %%
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
chi_square_value,p_value=calculate_bartlett_sphericity(df_num_scaled)
p_value
# Out:
# C:\ProgramData\Anaconda3\ac\lib\site-packages\factor_analyzer\factor_analyzer.py:118: RuntimeWarning: invalid value encountered in log
#   statistic = -np.log(corr_det) * (n - 1 - (2 * p + 5) / 6)
# nan

# %% [markdown]
# #### KMO Test
#
# The Kaiser-Meyer-Olkin (KMO) - measure of sampling adequacy (MSA) is an index used to examine how appropriate PCA is.
#
# Generally, if MSA is less than 0.5, PCA is not recommended, since no reduction is expected. On the other hand, MSA > 0.7 is expected to provide a considerable reduction is the dimension and extraction of meaningful components.

# %%
from factor_analyzer.factor_analyzer import calculate_kmo
kmo_all,kmo_model=calculate_kmo(df_num_scaled)
kmo_model
# Out:
# C:\ProgramData\Anaconda3\ac\lib\site-packages\factor_analyzer\utils.py:248: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn('The inverse of the variance-covariance matrix '
# 0.3052886806146504

# %%
# Step 1- Create the covariance Matrix
cov_matrix = np.cov(df_num_scaled.T)
print('Covariance Matrix \n%s', )
# Out:
# Covariance Matrix
# %s

# %%
# Step 2- Get eigen values and eigen vector
eig_vals, eig_vecs = np.linalg.eig(cov_matrix)
print('\n Eigen Values \n %s', )
print('\n')
print('Eigen Vectors \n %s', )
# Out:
#  Eigen Values
#  %s
#
#
# Eigen Vectors
#  %s

# %%
tot = sum(eig_vals)
var_exp = [( i /tot ) * 100 for i in sorted(eig_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)
print("Cumulative Variance Explained", cum_var_exp)
# Out:
# Cumulative Variance Explained [ 39.83712142  70.11768318  87.41145955  92.4313463   96.6914191
#   98.16387463  99.1436268   99.47933657  99.70933353  99.85342507
#   99.92057158  99.97198078  99.9902612   99.99472914  99.99741217
#   99.99861598  99.99920202  99.99973151  99.99985508  99.99994956
#   99.99998568  99.99999265  99.99999711  99.99999907  99.99999989
#   99.99999996 100.         100.         100.         100.
#  100.         100.         100.        ]

# %% [markdown]
# ### Scree plot

# %%
# Step 3 View Scree Plot to identify the number of components to be built
plt.figure(figsize=(12,7))
plt.xlabel('Number of Components',fontsize=15)
plt.ylabel('Variance Explained',fontsize=15)
plt.title('Scree Plot',fontsize=15)
plt.grid()
plt.show()

# %%
# Step 4 Apply PCA for the number of decided components to get the loadings and component output

# Using scikit learn PCA here. It does all the above steps and maps data to PCA dimensions in one shot
from sklearn.decomposition import PCA
# NOTE - we are generating only 8 PCA dimensions (dimensionality reduction from 33 to 8)
pca = PCA(n_components=8, random_state=123)
df_pca = pca.fit_transform(df_num_scaled)
df_pca.transpose() # Component output
# Out:
# array([[-3.05485615e+00,  5.69496634e-01,  6.13224464e-01,
#          6.46093907e+00, -5.02574930e+00, -4.71252727e+00,
#         -4.82665045e+00, -4.73710241e+00,  5.72179139e+00,
#         -9.35793577e-01,  1.95556089e+00, -1.56989147e+00,
#         -1.62704415e+00, -2.02083341e+00,  4.53247063e+00,
#         -5.94310919e-01,  3.51746214e+00, -9.18122998e-01,
#          1.36850679e+00,  4.02185474e+00,  3.47602286e+00,
#          5.40351035e+00,  6.06041013e-01, -3.33973911e+00,
#         -4.17555808e+00, -5.07755166e+00, -4.82367095e+00,
#          5.95895432e+00,  4.59225299e+00, -1.02325068e+00,
#         -3.06508057e+00,  1.38846199e+00,  1.34118289e+00],
#        [ 1.23608915e+00, -2.04685001e+00, -2.00260326e+00,
#          5.08733395e+00,  1.05346719e+00, -4.05975050e-01,
#         -5.21913684e-01, -3.62854658e-01,  5.17052094e+00,
#          4.09818257e+00, -5.03816235e+00, -4.42181518e+00,
#         -4.27653672e+00,  2.85661028e+00, -5.00632901e-01,
#          4.45981575e+00, -4.41140123e+00,  4.02830436e+00,
#         -1.37885639e+00, -4.10084049e+00, -4.42627608e+00,
#          1.03371769e+00, -1.08219278e-02,  3.28961203e+00,
#          1.99933297e+00,  1.35010416e+00, -4.84569970e-01,
#          5.48894215e+00, -3.69356855e+00, -4.42223313e+00,
#         -5.58180220e-01,  9.99135644e-01,  9.12922992e-01],
#        [-8.97965121e-02, -3.49748281e-03, -7.86377811e-03,
#         -2.05582274e+00, -1.02141148e+00, -1.72360982e+00,
#         -1.59515729e+00, -1.72214182e+00, -2.33033624e+00,
#          4.73514433e+00,  8.94442078e-01,  3.19660658e-01,
#          5.45278186e-01,  5.28594200e+00,  4.61310196e-01,
#          4.53071561e+00,  8.10367850e-01,  4.76589408e+00,
#          5.20414535e-01,  6.88869885e-01,  8.20616128e-01,
#          9.95624792e-01, -2.18852444e+00, -3.22344671e+00,
#         -2.44859473e+00, -1.77651246e+00, -1.61858130e+00,
#         -1.77072037e+00, -1.92265895e-01, -9.61103484e-02,
#          4.67119534e+00, -3.10679456e+00, -3.07428767e+00],
#        [-4.23487289e-01, -2.21132986e+00, -2.21972932e+00,
#         -9.82448144e-01,  2.77264888e-02, -1.73885733e+00,
#         -1.61533279e+00, -1.73055268e+00, -8.19404202e-01,
#          3.63663811e-01,  4.40252585e-01,  6.95379974e-01,
#          8.45080784e-01,  1.59153051e-01,  1.10773161e+00,
#          2.84286844e-01,  4.74070443e-01,  3.27871358e-01,
#         -2.15217813e+00,  3.66780302e-01,  4.81806315e-01,
#         -1.97622217e-01, -5.82717667e-01,  2.89493502e+00,
#          1.67661849e+00,  7.49100816e-01, -1.61469913e+00,
#         -9.30893471e-01,  3.03115201e-01,  1.25968153e+00,
#          6.30201436e-01,  2.05729899e+00,  2.07449720e+00],
#        [-9.57364483e-01, -6.70312282e-01, -6.91287945e-01,
#          2.77219396e-01,  2.89734251e+00, -8.82254868e-01,
#         -8.15841005e-01, -8.92902525e-01,  1.11017292e+00,
#         -4.89328966e-01, -2.60451691e-01,  1.60423236e+00,
#          1.47019759e+00, -4.09324642e-01,  1.38659990e-01,
#         -7.10374549e-01, -2.07743646e-01, -4.94695984e-01,
#         -8.15407792e-03, -3.04274380e-01, -1.78569168e-01,
#          1.52076699e+00,  2.43211494e-01, -6.47640013e-01,
#          1.22282927e+00,  2.17152901e+00, -8.44533254e-01,
#          1.39106546e+00, -3.26002034e-01,  1.00776510e+00,
#         -3.25545258e-02, -2.62089709e+00, -2.61048497e+00],
#        [ 2.76165607e+00,  1.24801360e+00,  1.25366639e+00,
#         -2.30207150e-01,  2.95808247e-01, -8.83663527e-01,
#         -9.11956674e-01, -8.77741185e-01, -4.19624280e-01,
#         -3.09395584e-01, -2.13460610e-01, -1.15299524e-01,
#         -2.01283371e-01, -2.93312783e-02,  9.97090922e-02,
#         -4.02754861e-01, -1.62697557e-01, -3.23783241e-01,
#          5.66847473e-02, -2.05114887e-01, -1.60796699e-01,
#          5.18364301e-01,  3.24056254e-01,  1.66239087e-01,
#          4.51970194e-01,  2.39455811e-01, -9.08045459e-01,
#         -4.56844864e-01, -2.77374907e-01, -4.76323030e-01,
#          8.06659055e-02,  3.82078290e-02,  3.12011584e-02],
#        [ 1.64091038e+00, -1.43487788e+00, -1.44524408e+00,
#         -1.64126744e-03,  2.14661529e-01,  2.78498254e-01,
#          2.86922211e-01,  2.74449047e-01, -6.69148676e-02,
#         -1.17148212e-01,  2.24323204e-02,  2.41383122e-02,
#          1.73950696e-02, -1.02461652e-01,  1.12680746e+00,
#         -1.42615074e-01,  5.76437062e-03, -1.01582684e-01,
#          7.16630923e-01, -2.18666494e-02, -1.13128118e-03,
#          2.41420111e-01, -5.57397313e-02, -8.88670803e-01,
#         -8.09566127e-01,  1.91532892e-01,  2.85841102e-01,
#         -7.33479567e-02, -2.92355568e-02, -8.05506573e-02,
#         -1.93329574e-01,  1.24073410e-01,  1.14446663e-01],
#        [ 2.82884034e-01, -1.14803608e-01, -1.12841312e-01,
#         -4.16134459e-02, -3.32280942e-01,  2.65711615e-01,
#          2.16402336e-01,  2.65541301e-01, -1.07836777e-01,
#          1.09308350e-01,  1.35688420e-01, -6.81814527e-02,
#         -1.43114731e-01, -1.39634462e-01,  3.36175714e-01,
#          1.02952730e-01,  1.56154169e-01,  8.84124157e-02,
#         -5.35876236e-01,  1.96264303e-01,  1.62100985e-01,
#          5.73079876e-01, -2.34560789e-01,  4.09346868e-01,
#          8.00931087e-01, -5.75196075e-01,  2.13884621e-01,
#         -2.00132945e-01,  2.24454636e-01, -2.68423327e-01,
#         -5.55592986e-01, -5.50225471e-01, -5.58978900e-01]])

# %%
# Loading of each feature on the components
pca.components_
# Out:
# array([[-2.16554219e-01,  1.48320998e-02,  1.82685824e-02,
#          2.53849500e-01, -2.45603119e-01, -2.36416449e-01,
#         -2.38891450e-01, -2.37179651e-01,  2.40431923e-01,
#         -6.29248736e-02,  8.33744262e-02, -8.99604473e-02,
#         -9.41293876e-02, -1.15281584e-01,  2.28210096e-01,
#         -5.01743182e-02,  1.52706858e-01, -6.21850813e-02,
#          6.92623043e-02,  1.73099936e-01,  1.51149505e-01,
#          2.50876090e-01,  2.59000891e-02, -2.04792218e-01,
#         -2.32266621e-01, -2.47864674e-01, -2.38982299e-01,
#          2.45146367e-01,  1.95539512e-01, -6.74863220e-02,
#         -1.66380249e-01,  7.81632893e-02,  7.41382411e-02],
#        [-7.88468883e-02, -2.72918414e-01, -2.71581982e-01,
#          9.86414040e-02, -5.50273411e-02, -1.00196077e-01,
#         -1.02881803e-01, -9.83456148e-02,  1.06054799e-01,
#          1.00681153e-01, -2.92059212e-01, -2.80882153e-01,
#         -2.76559269e-01,  2.57034444e-02, -1.38580320e-01,
#          1.17038983e-01, -2.53624425e-01,  9.80534216e-02,
#         -2.66304347e-01, -2.37632297e-01, -2.54684854e-01,
#         -6.11115583e-02, -1.87821043e-01,  6.66496144e-02,
#         -6.63250897e-03, -3.86501247e-02, -1.01459168e-01,
#          1.17543801e-01, -2.20158310e-01, -2.88325526e-01,
#         -1.55262041e-01, -8.57277915e-02, -9.22604365e-02],
#        [ 5.66600150e-02,  4.08355884e-02,  4.11326440e-02,
#         -8.18171503e-02, -4.82599252e-02, -8.86900492e-02,
#         -8.03129615e-02, -8.82372998e-02, -1.19584823e-01,
#          3.73622555e-01,  8.64612114e-02,  3.90960052e-02,
#          5.46318124e-02,  3.67977684e-01,  8.70154613e-02,
#          3.67619503e-01,  8.09997704e-02,  3.75442477e-01,
#          1.05712765e-01,  7.28410575e-02,  8.15061202e-02,
#          1.02924372e-01, -3.08656204e-01, -1.68660827e-01,
#         -1.32134326e-01, -8.15428514e-02, -8.14871297e-02,
#         -5.97139510e-02,  1.61831117e-02,  1.67206364e-02,
#          2.46226717e-01, -2.44082547e-01, -2.41429134e-01],
#        [ 3.36639100e-02, -2.56668218e-01, -2.59019509e-01,
#         -4.39308852e-02,  9.20343113e-02, -1.77095572e-01,
#         -1.63528293e-01, -1.76089524e-01, -2.89793499e-02,
#          1.12726296e-01,  7.32041245e-02,  1.31817901e-01,
#          1.45088260e-01,  1.01790411e-01,  1.86424705e-01,
#          9.80058144e-02,  7.73346240e-02,  1.09269806e-01,
#         -2.63792520e-01,  6.40269722e-02,  7.87598570e-02,
#          7.98285483e-02, -6.15020421e-02,  3.50531355e-01,
#          2.56043327e-01,  1.36642398e-01, -1.64172420e-01,
#         -1.27495057e-02,  4.90800392e-02,  1.70784633e-01,
#          1.11278362e-01,  3.63857126e-01,  3.68509731e-01],
#        [-1.88349013e-01, -1.45812478e-01, -1.50658731e-01,
#          2.86143452e-02,  3.17620632e-01, -1.35841574e-01,
#         -1.24379373e-01, -1.36723125e-01,  1.27691014e-01,
#         -9.78684990e-02, -1.03331503e-02,  2.15155465e-01,
#          2.10712307e-01, -9.69508006e-02,  1.98262252e-02,
#         -1.20211266e-01, -1.49496473e-03, -9.87764755e-02,
#         -6.42622156e-02, -1.37807881e-02,  1.59310986e-03,
#          1.60849395e-01,  1.49289308e-01, -2.10034453e-02,
#          1.61077018e-01,  2.62786228e-01, -1.27134309e-01,
#          1.41430471e-01, -6.32639373e-03,  1.84978438e-01,
#          4.09656545e-02, -4.45695363e-01, -4.43725890e-01],
#        [ 6.00268171e-01,  2.38031537e-01,  2.39214427e-01,
#         -1.30660397e-01, -1.27490963e-02, -2.77441885e-01,
#         -2.76204974e-01, -2.76211226e-01, -1.65535513e-01,
#         -1.12984340e-01, -6.41011555e-02, -5.00874346e-02,
#         -6.47145999e-02, -4.72021299e-02, -2.40383421e-02,
#         -1.23597651e-01, -5.34197549e-02, -1.15173847e-01,
#         -1.55852154e-01, -6.44226378e-02, -5.31941466e-02,
#          4.58148225e-02,  1.44722552e-01, -1.38987832e-02,
#          3.32639624e-02, -1.00645131e-02, -2.75899879e-01,
#         -1.74250548e-01, -7.52208537e-02, -1.15376650e-01,
#          8.03417814e-02, -5.52827939e-02, -5.61396450e-02],
#        [ 4.41391350e-01, -4.84749544e-01, -4.89212625e-01,
#         -6.33661587e-02, -2.11265488e-02,  6.14290252e-02,
#          6.37012024e-02,  6.03462480e-02, -8.17660000e-02,
#         -9.19943065e-02,  3.77491201e-02,  5.34648353e-03,
#          1.34746921e-02, -5.75589242e-02,  2.18423353e-01,
#         -9.36816234e-02,  2.34136951e-02, -8.81377347e-02,
#          2.03355097e-01,  1.61331444e-02,  2.20051110e-02,
#         -2.64110884e-03,  5.15892903e-02, -2.97797201e-01,
#         -2.80582454e-01, -2.41752320e-02,  6.37135734e-02,
#         -1.07969667e-01,  2.09758417e-02, -1.12497553e-04,
#          2.54215448e-02, -1.41004992e-02, -1.63506210e-02],
#        [ 1.67909051e-01, -4.41132647e-02, -4.04420239e-02,
#          5.20163202e-02, -2.30320822e-01,  1.71681131e-01,
#          1.51788335e-01,  1.71819341e-01,  2.44322184e-04,
#         -5.81913091e-02,  1.24409807e-01, -7.54477563e-02,
#         -1.01403070e-01,  3.94053302e-02,  2.17678183e-01,
#         -9.12643877e-02,  1.15000026e-01, -6.25161775e-02,
#         -3.51395995e-01,  1.35880243e-01,  1.16122852e-01,
#          2.83107830e-01, -9.50497470e-02,  2.74220692e-01,
#          3.49318290e-01, -2.99509026e-01,  1.51646118e-01,
#         -7.72426181e-02,  1.67195211e-01, -1.40037318e-01,
#         -6.22358065e-02, -2.28409481e-01, -2.38931393e-01]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.39837121, 0.30280562, 0.17293776, 0.05019887, 0.04260073,
#        0.01472456, 0.00979752, 0.0033571 ])

# %% [markdown]
# Let's create a dataframe of component loading against each field and identify the pattern

# %%
df_pca_loading = pd.DataFrame(pca.components_,columns=list(df_num_scaled))
df_pca_loading.shape
# Out:
# (8, 33)

# %%
df_pca_loading.head(8)
# Out:
#         age  gross_income  nettakehome  balance_tenure  completed_tenure  \
# 0 -0.216554      0.014832     0.018269        0.253850         -0.245603
# 1 -0.078847     -0.272918    -0.271582        0.098641         -0.055027
# 2  0.056660      0.040836     0.041133       -0.081817         -0.048260
# 3  0.033664     -0.256668    -0.259020       -0.043931          0.092034
# 4 -0.188349     -0.145812    -0.150659        0.028614          0.317621
# 5  0.600268      0.238032     0.239214       -0.130660         -0.012749
# 6  0.441391     -0.484750    -0.489213       -0.063366         -0.021127
# 7  0.167909     -0.044113    -0.040442        0.052016         -0.230321
#
#    current_interest_rate  current_interest_rate_max  \
# 0              -0.236416                  -0.238891
# 1              -0.100196                  -0.102882
# 2              -0.088690                  -0.080313
# 3              -0.177096                  -0.163528
# 4              -0.135842                  -0.124379
# 5              -0.277442                  -0.276205
# 6               0.061429                   0.063701
# 7               0.171681                   0.151788
#
#    current_interest_rate_min  current_tenor  diff_emi_amount_max_min  ...  \
# 0                  -0.237180       0.240432                -0.062925  ...
# 1                  -0.098346       0.106055                 0.100681  ...
# 2                  -0.088237      -0.119585                 0.373623  ...
# 3                  -0.176090      -0.028979                 0.112726  ...
# 4                  -0.136723       0.127691                -0.097868  ...
# 5                  -0.276211      -0.165536                -0.112984  ...
# 6                   0.060346      -0.081766                -0.091994  ...
# 7                   0.171819       0.000244                -0.058191  ...
#
#    num_emi_changes  num_low_freq_transactions  num_of_emi_transactions  \
# 0        -0.204792                  -0.232267                -0.247865
# 1         0.066650                  -0.006633                -0.038650
# 2        -0.168661                  -0.132134                -0.081543
# 3         0.350531                   0.256043                 0.136642
# 4        -0.021003                   0.161077                 0.262786
# 5        -0.013899                   0.033264                -0.010065
# 6        -0.297797                  -0.280582                -0.024175
# 7         0.274221                   0.349318                -0.299509
#
#    orignal_interest_rate  orignal_tenor  outstanding_principal  paid_interest  \
# 0              -0.238982       0.245146               0.195540      -0.067486
# 1              -0.101459       0.117544              -0.220158      -0.288326
# 2              -0.081487      -0.059714               0.016183       0.016721
# 3              -0.164172      -0.012750               0.049080       0.170785
# 4              -0.127134       0.141430              -0.006326       0.184978
# 5              -0.275900      -0.174251              -0.075221      -0.115377
# 6               0.063714      -0.107970               0.020976      -0.000112
# 7               0.151646      -0.077243               0.167195      -0.140037
#
#    paid_principal  pre_emi_dueamt  pre_emi_received_amt
# 0       -0.166380        0.078163              0.074138
# 1       -0.155262       -0.085728             -0.092260
# 2        0.246227       -0.244083             -0.241429
# 3        0.111278        0.363857              0.368510
# 4        0.040966       -0.445695             -0.443726
# 5        0.080342       -0.055283             -0.056140
# 6        0.025422       -0.014100             -0.016351
# 7       -0.062236       -0.228409             -0.238931
#
# [8 rows x 33 columns]

# %% [markdown]
# Let's identify which features have maximum loading across the components.

# %%
from matplotlib.patches import Rectangle

# %%
fig,ax = plt.subplots(figsize=(22, 10), facecolor='w', edgecolor='k')
ax = sns.heatmap(df_pca_loading, annot=True, vmax=1.0, vmin=0, cmap='Blues', cbar=False, fmt='.2g', ax=ax,
                 yticklabels=['PC0','PC1','PC2','PC3','PC4','PC5','PC6','PC7'])

column_max = df_pca_loading.abs().idxmax(axis=0)

for col, variable in enumerate(df_pca_loading.columns):
    position = df_pca_loading.index.get_loc(column_max[variable])
    ax.add_patch(Rectangle((col, position),1,1, fill=False, edgecolor='red', lw=3))

# %%
df_pca = pd.DataFrame(df_pca,columns=['pc_loan_repayment','pc_balance_loan','pc_interest_rate','pc_tenure',
                                  'pc_pre_emi','pc_emi','pc_receiveable','pc_income'])
df_pca.head()
# Out:
#    pc_loan_repayment  pc_balance_loan  pc_interest_rate  pc_tenure  \
# 0          -3.054856         1.236089         -0.089797  -0.423487
# 1           0.569497        -2.046850         -0.003497  -2.211330
# 2           0.613224        -2.002603         -0.007864  -2.219729
# 3           6.460939         5.087334         -2.055823  -0.982448
# 4          -5.025749         1.053467         -1.021411   0.027726
#
#    pc_pre_emi    pc_emi  pc_receiveable  pc_income
# 0   -0.957364  2.761656        1.640910   0.282884
# 1   -0.670312  1.248014       -1.434878  -0.114804
# 2   -0.691288  1.253666       -1.445244  -0.112841
# 3    0.277219 -0.230207       -0.001641  -0.041613
# 4    2.897343  0.295808        0.214662  -0.332281

# %%
df_pca.shape
# Out:
# (33, 8)

# %% [markdown]
# ### EDA (Categorical Fields & Principal Components)

# %%
df_new = pd.concat([df_cat, df_pca], axis=1)

# %%
df_new.shape
# Out:
# (2319, 13)

# %%
df_new.head()
# Out:
#   loan_account gender marital_status qualification     city  \
# 0        LA492      F              M            UG  MADURAI
# 1        LA498      M              M          GRAD  MADURAI
# 2        LA500      M              M            UG  MADURAI
# 3        LA531      M              M            UG  MADURAI
# 4        LA552      M              S          GRAD  MADURAI
#
#    pc_loan_repayment  pc_balance_loan  pc_interest_rate  pc_tenure  \
# 0          -3.054856         1.236089         -0.089797  -0.423487
# 1           0.569497        -2.046850         -0.003497  -2.211330
# 2           0.613224        -2.002603         -0.007864  -2.219729
# 3           6.460939         5.087334         -2.055823  -0.982448
# 4          -5.025749         1.053467         -1.021411   0.027726
#
#    pc_pre_emi    pc_emi  pc_receiveable  pc_income
# 0   -0.957364  2.761656        1.640910   0.282884
# 1   -0.670312  1.248014       -1.434878  -0.114804
# 2   -0.691288  1.253666       -1.445244  -0.112841
# 3    0.277219 -0.230207       -0.001641  -0.041613
# 4    2.897343  0.295808        0.214662  -0.332281

# %%
df_new.describe(include='all')
# Out:
#        loan_account gender marital_status qualification    city  \
# count          2319   2319           2319          2319    2319
# unique         2319      2              2             8      17
# top          LA2025      M              M            UG  MUMBAI
# freq              1   1994           2086          1548     607
# mean            NaN    NaN            NaN           NaN     NaN
# std             NaN    NaN            NaN           NaN     NaN
# min             NaN    NaN            NaN           NaN     NaN
# 25%             NaN    NaN            NaN           NaN     NaN
# 50%             NaN    NaN            NaN           NaN     NaN
# 75%             NaN    NaN            NaN           NaN     NaN
# max             NaN    NaN            NaN           NaN     NaN
#
#         pc_loan_repayment  pc_balance_loan  pc_interest_rate     pc_tenure  \
# count        3.300000e+01     3.300000e+01      3.300000e+01  3.300000e+01
# unique                NaN              NaN               NaN           NaN
# top                   NaN              NaN               NaN           NaN
# freq                  NaN              NaN               NaN           NaN
# mean        -1.413011e-16    -3.364312e-17      2.153160e-16  5.382900e-17
# std          3.681993e+00     3.210117e+00      2.425961e+00  1.307031e+00
# min         -5.077552e+00    -5.038162e+00     -3.223447e+00 -2.219729e+00
# 25%         -3.065081e+00    -2.046850e+00     -1.770720e+00 -9.308935e-01
# 50%         -5.943109e-01    -3.628547e-01     -8.979651e-02  3.031152e-01
# 75%          3.476023e+00     1.999333e+00      8.103678e-01  6.953800e-01
# max          6.460939e+00     5.488942e+00      5.285942e+00  2.894935e+00
#
#           pc_pre_emi        pc_emi  pc_receiveable     pc_income
# count   3.300000e+01  3.300000e+01    3.300000e+01  3.300000e+01
# unique           NaN           NaN             NaN           NaN
# top              NaN           NaN             NaN           NaN
# freq             NaN           NaN             NaN           NaN
# mean   -1.749442e-16  1.619075e-17   -2.203624e-16  5.719331e-17
# std     1.204058e+00  7.078807e-01    5.774270e-01  3.380033e-01
# min    -2.620897e+00 -9.119567e-01   -1.445244e+00 -5.751961e-01
# 25%    -6.912879e-01 -3.237832e-01   -1.015827e-01 -2.001329e-01
# 50%    -2.604517e-01 -1.607967e-01   -1.131281e-03  8.841242e-02
# 75%     1.007765e+00  1.662391e-01    2.146615e-01  2.164023e-01
# max     2.897343e+00  2.761656e+00    1.640910e+00  8.009311e-01

# %%
fig,ax = plt.subplots(figsize=(22,7))
sns.boxplot(x='city',y='pc_loan_repayment', data=df_new)
# Out:
# <AxesSubplot:xlabel='city', ylabel='pc_loan_repayment'>

# %% [markdown]
# From above plots we observe that for Ahmedabad & Surat the loan repayment amount is comparatively lower than other cities.
#
# Loan repayment amount is highest for Chennai compared to other cities

# %%
fig,ax = plt.subplots(figsize=(22,7))
sns.boxplot(x='city',y='pc_interest_rate', data=df_new)
# Out:
# <AxesSubplot:xlabel='city', ylabel='pc_interest_rate'>

# %% [markdown]
# Interest rate is highest for Ahmedabad and lowest for Tirupur

# %%
fig,ax = plt.subplots(figsize=(22,7))
sns.boxplot(x='city',y='pc_pre_emi', data=df_new)
# Out:
# <AxesSubplot:xlabel='city', ylabel='pc_pre_emi'>

# %% [markdown]
# City of Erode seems to have highest pre-emi payments

# %% [markdown]
# #### Observation
#
# - From above plots we observe that for Ahmedabad city, loan repayment amount is comparatively lower than other cities however, the interest rate charged to the customers is much higher
#
# - For Erode city, loan repayment amount is low, interest rate is comparative high and the pre-emi amount paid by customers from this city is also high

# %% [markdown]
# ### Apply rules & analyze patterns in data

# %% [markdown]
# #### Case 1 - Advance Closure
# Customer who
# - has to pay lesser loan,
# - has done some payment as part of pre-emi and
# - has an high income
# have higher chances to do *advance payment* and close the loan in advance thus causing loss to the financial institute
#
# Let's create a subset dataframe *df_adv_closure* which satisfies all above conditions and analyze it further

# %%
cond1 = df_new.pc_loan_repayment < df_new.pc_loan_repayment.quantile(0.25) # customers paying lesser loan
cond2 = df_new.pc_pre_emi > df_new.pc_pre_emi.quantile(0.75) # customers who have paid high pre-emi
cond3 = df_new.pc_income > df_new.pc_income.quantile(0.75) # customers who have high income
df_adv_closure = df_new[cond1 & cond2 & cond3] # Find customers satisifying all above conditions

# %%
df_adv_closure.index
# Out:
# Int64Index([24], dtype='int64')

# %% [markdown]
# Above index corresponds to the rows or loan accounts which satisfy the Case 1 conditions. Let's create a new field 'advance_closure' which will hold a value of 1 for above indexed rows

# %%
df_adv_closure=df_adv_closure.assign(advance_closure=1)
df_adv_closure.head()
# Out:
#    loan_account gender marital_status qualification        city  \
# 24        LA660      M              M            UG  COIMBATORE
#
#     pc_loan_repayment  pc_balance_loan  pc_interest_rate  pc_tenure  \
# 24          -4.175558         1.999333         -2.448595   1.676618
#
#     pc_pre_emi   pc_emi  pc_receiveable  pc_income  advance_closure
# 24    1.222829  0.45197       -0.809566   0.800931                1

# %% [markdown]
# Let's merge *advance_closure* field with our original dataframe for the selected index and analyze further

# %%
df_merge = df.merge(df_adv_closure['advance_closure'],left_index=False,left_on=df.index, right_index=True, right_on=df_adv_closure.index, how='left')
df_merge.head(252)
# Out:
#     loan_account  age gender marital_status qualification   gross_income  \
# 0          LA492   39      F              M            UG   63542.344735
# 1          LA498   51      M              M          GRAD   81130.025032
# 2          LA500   41      M              M            UG   56298.592500
# 3          LA531   42      M              M            UG   74314.142100
# 4          LA552   27      M              S          GRAD   64255.460240
# ..           ...  ...    ...            ...           ...            ...
# 247       LA1309   44      M              M            UG   91110.639510
# 248       LA1310   24      M              S          GRAD  150129.580000
# 249       LA1317   40      F              M        OTHERS   47290.817700
# 250       LA1319   33      M              M            UG   78067.381600
# 251       LA1321   24      M              S          GRAD   26422.806080
#
#        nettakehome  balance_tenure       city  completed_tenure  ...  \
# 0     63542.344735             111    MADURAI                70  ...
# 1     81130.025032             107    MADURAI                68  ...
# 2     56298.592500              50    MADURAI                70  ...
# 3     74314.142100             110    MADURAI                70  ...
# 4     64255.460240             112    MADURAI                69  ...
# ..             ...             ...        ...               ...  ...
# 247   91110.639510             164     MUMBAI                51  ...
# 248  150129.580000             123    CHENNAI                57  ...
# 249   47290.817700             128     MUMBAI                52  ...
# 250   78067.381600              36  TUTICORIN                51  ...
# 251   26422.806080             204  TUTICORIN                37  ...
#
#      num_low_freq_transactions  num_of_emi_transactions  \
# 0                           10                       73
# 1                           11                       73
# 2                           10                       73
# 3                           17                       72
# 4                           10                       71
# ..                         ...                      ...
# 247                          7                       52
# 248                          9                       58
# 249                          9                       53
# 250                          1                       54
# 251                          2                       52
#
#      orignal_interest_rate  orignal_tenor  outstanding_principal  \
# 0                17.479728            180           9.882910e+05
# 1                17.479728            180           1.206218e+06
# 2                17.479728            120           7.137100e+05
# 3                17.479728            180           1.744746e+06
# 4                17.479728            180           1.502039e+06
# ..                     ...            ...                    ...
# 247              17.479728            180           3.142253e+06
# 248              18.104004            180           3.691821e+06
# 249              17.479728            180           9.093694e+05
# 250              17.479728            120           3.683910e+05
# 251              15.606900            240           6.829064e+05
#
#      paid_interest  paid_principal  pre_emi_dueamt  pre_emi_received_amt  \
# 0     9.340537e+05   212745.625226    39959.331336          39959.331336
# 1     1.069305e+06   295078.188194    78774.632736          78774.632736
# 2     8.303592e+05   487326.621863    37918.629288          37918.629288
# 3     1.567354e+06   357068.193072    29375.950152          29375.950152
# 4     1.355995e+06   299516.018579    46048.309200          46048.309200
# ..             ...             ...             ...                   ...
# 247   9.194536e+04    10468.535613    27054.762000          27054.762000
# 248   2.674090e+06   511806.751178    42344.567496          42344.567496
# 249   1.915338e+05    28940.479137    11811.336096          11811.336096
# 250   3.669107e+05   457321.724004    29758.029648          29758.029648
# 251   3.619744e+05    30209.074088   135916.498632         135916.498632
#
#      advance_closure
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 247              NaN
# 248              NaN
# 249              NaN
# 250              NaN
# 251              NaN
#
# [252 rows x 39 columns]

# %%
df_merge.advance_closure.fillna(0, inplace=True)

# %%
df_merge.advance_closure.value_counts()
# Out:
# 0.0    2318
# 1.0       1
# Name: advance_closure, dtype: int64

# %% [markdown]
# #### Analyze data for probable customers who may payoff the loan in advance

# %%
sns.boxplot(df_merge.advance_closure, df_merge.num_emi_changes)
# Out:
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='advance_closure', ylabel='num_emi_changes'>

# %%
sns.boxplot(df_merge.advance_closure, df_merge.outstanding_principal)
# Out:
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='advance_closure', ylabel='outstanding_principal'>

# %%
sns.boxplot(df_merge.advance_closure, df_merge.paid_interest)
# Out:
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='advance_closure', ylabel='paid_interest'>

# %% [markdown]
# #### Observation:
#
# 28 customers have low outstanding principal, have paid less interest so far and we also see that there are more changes in emi value being paid. Hence, there is high probability that these customers may close the loans in advance

# %% [markdown]
# #### Case 2 - Loan Default:
#
# Customers
# - with high loan,
# - low income and
# - high loan interest rate
# are probable customers to default.
#
# Let's create a subset dataframe *df_delay_closure* which satisfies all above conditions and analyze further

# %%
cond1 = df_new.pc_loan_repayment > df_new.pc_loan_repayment.quantile(0.75)# customers paying higher loan
cond2 = df_new.pc_income < df_new.pc_income.quantile(0.25) # customers with lesser income
cond3 = df_new.pc_interest_rate > df_new.pc_interest_rate.quantile(0.75) # customers paying higher interest

df_delay_closure = df_new[cond1 & cond2 & cond3]# Find customers satisifying all above conditions

# %%
df_delay_closure.index
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# Above index corresponds to the rows or loan accounts which satisfy the Case 2 conditions. Let's create a new field *'delay_closure'* which will hold a value of 1 for above indexed rows

# %%
df_delay_closure = df_delay_closure.assign(delay_closure=1)
df_delay_closure.head()
# Out:
# Empty DataFrame
# Columns: [loan_account, gender, marital_status, qualification, city, pc_loan_repayment, pc_balance_loan, pc_interest_rate, pc_tenure, pc_pre_emi, pc_emi, pc_receiveable, pc_income, delay_closure]
# Index: []

# %% [markdown]
# Let's merge the *df_delay_closure* with original dataframe *'df'* and just add the *'delay_closure'* field

# %%
df_merge = df.merge(df_delay_closure['delay_closure'],left_index=False,left_on=df.index, right_index=True, 
                    right_on=df_delay_closure.index, how='left')
df_merge.head(79)
# Out:
#    loan_account  age gender marital_status qualification   gross_income  \
# 0         LA492   39      F              M            UG   63542.344735
# 1         LA498   51      M              M          GRAD   81130.025032
# 2         LA500   41      M              M            UG   56298.592500
# 3         LA531   42      M              M            UG   74314.142100
# 4         LA552   27      M              S          GRAD   64255.460240
# ..          ...  ...    ...            ...           ...            ...
# 74        LA843   52      M              M           PRF  225194.370000
# 75        LA844   34      F              M            UG   10947.448974
# 76        LA849   27      M              M          GRAD  292752.681000
# 77        LA850   35      M              M            UG  131363.382500
# 78        LA852   41      F              M        OTHERS   34812.047010
#
#       nettakehome  balance_tenure             city  completed_tenure  ...  \
# 0    63542.344735             111          MADURAI                70  ...
# 1    81130.025032             107          MADURAI                68  ...
# 2    56298.592500              50          MADURAI                70  ...
# 3    74314.142100             110          MADURAI                70  ...
# 4    64255.460240             112          MADURAI                69  ...
# ..            ...             ...              ...               ...  ...
# 74  225194.370000             127          CHENNAI                53  ...
# 75   10947.448974             118          MADURAI                62  ...
# 76  292752.681000             174          CHENNAI                 6  ...
# 77  131363.382500             152  TIRUCHIRAPPALLI                28  ...
# 78   34812.047010             115          MADURAI                66  ...
#
#     num_low_freq_transactions  num_of_emi_transactions  orignal_interest_rate  \
# 0                          10                       73              17.479728
# 1                          11                       73              17.479728
# 2                          10                       73              17.479728
# 3                          17                       72              17.479728
# 4                          10                       71              17.479728
# ..                        ...                      ...                    ...
# 74                          7                       54              17.479728
# 75                          7                       66              16.231176
# 76                          2                        6              17.479728
# 77                          2                       28              17.479728
# 78                         11                       66              17.479728
#
#     orignal_tenor  outstanding_principal  paid_interest  paid_principal  \
# 0             180           9.882910e+05   9.340537e+05   212745.625226
# 1             180           1.206218e+06   1.069305e+06   295078.188194
# 2             120           7.137100e+05   8.303592e+05   487326.621863
# 3             180           1.744746e+06   1.567354e+06   357068.193072
# 4             180           1.502039e+06   1.355995e+06   299516.018579
# ..            ...                    ...            ...             ...
# 74            180           5.300601e+06   7.802191e+05   104063.819673
# 75            180           6.308025e+05   4.930330e+05   119845.441122
# 76            180           3.566369e+06   2.721834e+05    36741.212113
# 77            180           3.549472e+06   1.208924e+06   203767.876342
# 78            180           3.016782e+06   2.592522e+06   586328.072098
#
#     pre_emi_dueamt  pre_emi_received_amt  delay_closure
# 0     39959.331336          39959.331336            NaN
# 1     78774.632736          78774.632736            NaN
# 2     37918.629288          37918.629288            NaN
# 3     29375.950152          29375.950152            NaN
# 4     46048.309200          46048.309200            NaN
# ..             ...                   ...            ...
# 74    58747.483200          58747.483200            NaN
# 75    35246.281368          35246.281368            NaN
# 76    30919.728000          30919.728000            NaN
# 77    19324.830000          19324.830000            NaN
# 78    17474.063424          17474.063424            NaN
#
# [79 rows x 39 columns]

# %%
df_merge.delay_closure.fillna(0, inplace=True)

# %%
df_merge.delay_closure.value_counts()
# Out:
# 0.0    2319
# Name: delay_closure, dtype: int64

# %% [markdown]
# #### Analyze data for probable customers who may default

# %%
sns.boxplot(df_merge.delay_closure, df_merge.net_ltv)
# Out:
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='delay_closure', ylabel='net_ltv'>

# %%
sns.boxplot(df_merge.delay_closure, df_merge.outstanding_principal)
# Out:
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='delay_closure', ylabel='outstanding_principal'>

# %%
sns.boxplot(df_merge.delay_closure, df_merge.paid_interest)
# Out:
# C:\ProgramData\Anaconda3\ac\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='delay_closure', ylabel='paid_interest'>

# %% [markdown]
# #### Observation:
# 54 customers have high outstanding principal, have interest to be paid and we also see that their loan to value ratio is higher. Hence, there is high probability that these customers may default in future

# %% [markdown]
# ### Conclusion

# %% [markdown]
# With help of PCA we have been able to reduce 33 numeric features into 8 components which is able to explain 82% of variance in the data
#
# With help of reduced components we have been able to observe some patterns. Using some rules around business context we are able to shortlist few customers who need to be monitored closely either for advance closure (28 out of 2319) or for possible default case (54 out of 2319).
#
# Using the components additional rules can be derived and analyzed.
#
# Unsupervised learning like clustering can further be applied on the data to segment the customers based on the components created and further analyzed.
